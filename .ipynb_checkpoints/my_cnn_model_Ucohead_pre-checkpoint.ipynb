# %% [markdown]
# ## MY CNN model
#
# Test CNN model

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
tf.config.list_physical_devices("GPU")
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'),
#  PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %%
BATCH_SIZE = 32
# IMG_SIZE = (500,500)
# IMG_W = 500
# IMG_H = 500
IMG_SIZE = (40,40)
IMG_W = 40
IMG_H = 40
# IMG_SIZE = (200,200)
# IMG_W = 200
# IMG_H = 200

# %%
train_dataset = image_dataset_from_directory("../dataset/train/",
                                            shuffle=True,
                                            batch_size=BATCH_SIZE,
                                            image_size=IMG_SIZE)
# Out:
# Found 7818 files belonging to 10 classes.

# %%
validation_dataset = image_dataset_from_directory("../dataset/test/",
                                                 shuffle=True,
                                                 batch_size=BATCH_SIZE,
                                                 image_size=IMG_SIZE)
# Out:
# Found 3806 files belonging to 10 classes.

# %%
class_names = train_dataset.class_names
class_names
# Out:
# ['n0', 'n1', 'n2', 'n3', 'n4', 'n5', 'n6', 'n7', 'n8', 'n9']

# %%
plt.figure(figsize=(5,5))
for images, labels in train_dataset.take(1):
    for i in range(9):
        ax = plt.subplot(3,3,i+1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %%
val_batches = tf.data.experimental.cardinality(validation_dataset)
test_dataset = validation_dataset.take(val_batches//5)
validation_dataset = validation_dataset.skip(val_batches//5)

# %%
print("Number of validation batches : %d" %tf.data.experimental.cardinality(validation_dataset))
print("Number of test batches : %d" %tf.data.experimental.cardinality(test_dataset))
# Out:
# Number of validation batches : 96
# Number of test batches : 23

# %%
AUTOTUNE =tf.data.experimental.AUTOTUNE

train_dataset = train_dataset.prefetch(buffer_size=AUTOTUNE)
validation_dataset = validation_dataset.prefetch(buffer_size=AUTOTUNE)
test_dataset = test_dataset.prefetch(buffer_size=AUTOTUNE)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D, BatchNormalization, Dropout

# %%
rescale = tf.keras.layers.experimental.preprocessing.Rescaling(1./127.5, offset = -1)

# %%
#### Ucohead original
def my_model(input_shape, drop_rate): # dr0.2/
    model = Sequential([
        Conv2D(filters=32, input_shape=input_shape, kernel_size=(3,3), activation = 'relu'),
        MaxPooling2D(pool_size=(2,2)),
        Conv2D(filters=64, kernel_size=(3,3), activation='relu'),
        MaxPooling2D(pool_size=(2,2)),
        Conv2D(filters=128, kernel_size=(3,3), activation='relu'),
        MaxPooling2D(pool_size=(2,2)),
        Dropout(drop_rate),
        Flatten(),
        Dropout(drop_rate),
        Dense(units=256, activation='relu'),
        Dropout(drop_rate),
        Dense(units=256, activation='relu')
#         Dense(units=1, activation='softmax')
    ])
    return model

# %%
# ##### ref01
def my_model(input_shape, drop_rate): # dr0.2/
    model = Sequential([
        Conv2D(filters=32, input_shape=input_shape, kernel_size=(3,3), activation = 'relu'),
        MaxPooling2D(pool_size=(2,2)),
        Conv2D(filters=64, kernel_size=(3,3), activation='relu'),
        MaxPooling2D(pool_size=(2,2)),
        Conv2D(filters=128, kernel_size=(3,3), activation='relu'),
        MaxPooling2D(pool_size=(2,2)),
        Dropout(drop_rate),
        Flatten(),
        Dropout(drop_rate),
        Dense(units=256, activation='relu'),
        Dropout(drop_rate),
        Dense(units=256, activation='relu')
#         Dense(units=1, activation='softmax')
    ])
    return model

# %%
drop_rate = 0.4 #looks it works better than 0.5

model = my_model(first_image.shape, drop_rate)

# %%
model.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_9 (Conv2D)            (None, 298, 298, 32)      896
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 149, 149, 32)      0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 147, 147, 64)      18496
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 73, 73, 64)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 71, 71, 128)       73856
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 35, 35, 128)       0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 35, 35, 128)       0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 156800)            0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 156800)            0
# _________________________________________________________________
# dense_9 (Dense)              (None, 256)               40141056
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 256)               65792
# =================================================================
# Total params: 40,300,096
# Trainable params: 40,300,096
# Non-trainable params: 0
# _________________________________________________________________

# %%
prediction_layer = tf.keras.layers.Dense(1, activation="relu")  
#default -linear, 0.5375
#softmax, 0.4000
#relu, 0.6250

# %%
inputs = tf.keras.Input(shape=(IMG_H, IMG_W, 3))
x = data_augmentation(inputs)
x = rescale(x)
x = model(x)
outputs = prediction_layer(x)
cnn_model = tf.keras.Model(inputs, outputs)

# %%
base_lr = 0.0001
cnn_model.compile(optimizer=tf.keras.optimizers.Adam(lr=base_lr), 
                  loss = tf.keras.losses.BinaryCrossentropy(from_logits=True),
                  metrics=['accuracy'])

# %%
cnn_model.summary()
# Out:
# Model: "functional_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 300, 300, 3)]     0
# _________________________________________________________________
# sequential_10 (Sequential)   (None, 300, 300, 3)       0
# _________________________________________________________________
# rescaling_2 (Rescaling)      (None, 300, 300, 3)       0
# _________________________________________________________________
# sequential_11 (Sequential)   (None, 256)               40300096
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 40,300,353
# Trainable params: 40,300,353
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import Callback, ModelCheckpoint, EarlyStopping

class TrainingCallback(Callback):
    def on_train_begin(self, logs=None):
        print("Starting training ...")
    def on_train_end(self, logs=None):
        print("Finished training!")

early_stopping = EarlyStopping(monitor='val_accuracy', verbose=1, patience=5)

# %%
initial_epochs = 200
loss0, accuracy0 = cnn_model.evaluate(validation_dataset)
# Out:
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6931 - accuracy: 0.6125

# %%
print("initial loss : {:.2f}".format(loss0))
print("initial accuracy : {:.2f}".format(accuracy0))
# Out:
# initial loss : 0.69
# initial accuracy : 0.61

# %%
# history = cnn_model.fit(train_dataset,
#                        epochs=initial_epochs,
#                        validation_data=validation_dataset,
#                        callbacks=[TrainingCallback(), early_stopping])
history = cnn_model.fit(train_dataset,
                       epochs=initial_epochs,
                       validation_data=validation_dataset,
                       callbacks=[TrainingCallback()])
# Out:
# Starting training ...
# Epoch 1/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6933 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6125
# Epoch 2/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5500
# Epoch 3/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 4/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5375
# Epoch 5/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5750
# Epoch 6/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5750
# Epoch 7/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5750
# Epoch 8/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5625
# Epoch 9/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5750
# Epoch 10/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 11/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 12/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5750
# Epoch 13/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 14/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 15/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6125
# Epoch 16/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 17/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6375
# Epoch 18/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6375
# Epoch 19/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5750
# Epoch 20/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 21/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6500
# Epoch 22/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 23/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 24/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6125
# Epoch 25/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6375
# Epoch 26/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5625
# Epoch 27/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6125
# Epoch 28/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6500
# Epoch 29/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6375
# Epoch 30/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5500
# Epoch 31/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6125
# Epoch 32/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 33/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6250
# Epoch 34/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 35/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5750
# Epoch 36/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 37/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 38/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 39/200
# 57/57 [==============================] - 2s 34ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 40/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6125
# Epoch 41/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 42/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6250
# Epoch 43/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5750
# Epoch 44/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5750
# Epoch 45/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6125
# Epoch 46/200
# 57/57 [==============================] - 2s 34ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5750
# Epoch 47/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6500
# Epoch 48/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5750
# Epoch 49/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 50/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 51/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5750
# Epoch 52/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 53/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 54/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 55/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6125
# Epoch 56/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6250
# Epoch 57/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 58/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5750
# Epoch 59/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5500
# Epoch 60/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6500
# Epoch 61/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6500
# Epoch 62/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5750
# Epoch 63/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6250
# Epoch 64/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 65/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5625
# Epoch 66/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5375
# Epoch 67/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6250
# Epoch 68/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 69/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6125
# Epoch 70/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 71/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5625
# Epoch 72/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6125
# Epoch 73/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6500
# Epoch 74/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 75/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5625
# Epoch 76/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5750
# Epoch 77/200
# 57/57 [==============================] - 2s 30ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6375
# Epoch 78/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6375
# Epoch 79/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 80/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6125
# Epoch 81/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6375
# Epoch 82/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 83/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 84/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6500
# Epoch 85/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6125
# Epoch 86/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 87/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5750
# Epoch 88/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6375
# Epoch 89/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 90/200
# 57/57 [==============================] - 2s 34ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 91/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6375
# Epoch 92/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6125
# Epoch 93/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 94/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6125
# Epoch 95/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6125
# Epoch 96/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 97/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 98/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 99/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 100/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5750
# Epoch 101/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6125
# Epoch 102/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 103/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5625
# Epoch 104/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 105/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6125
# Epoch 106/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 107/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 108/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6125
# Epoch 109/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 110/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5750
# Epoch 111/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6375
# Epoch 112/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6125
# Epoch 113/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6250
# Epoch 114/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5750
# Epoch 115/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6375
# Epoch 116/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5750
# Epoch 117/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 118/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 119/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 120/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6125
# Epoch 121/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6125
# Epoch 122/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 123/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6250
# Epoch 124/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5750
# Epoch 125/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5500
# Epoch 126/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 127/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5750
# Epoch 128/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6250
# Epoch 129/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5750
# Epoch 130/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 131/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 132/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6625
# Epoch 133/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 134/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 135/200
# 57/57 [==============================] - 2s 34ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5625
# Epoch 136/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 137/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6125
# Epoch 138/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 139/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6125
# Epoch 140/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 141/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 142/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5625
# Epoch 143/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 144/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 145/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6125
# Epoch 146/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5750
# Epoch 147/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 148/200
# 57/57 [==============================] - 2s 34ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 149/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6125
# Epoch 150/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 151/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 152/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 153/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6125
# Epoch 154/200
# 57/57 [==============================] - 2s 34ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6500
# Epoch 155/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6375
# Epoch 156/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 157/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6250
# Epoch 158/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5750
# Epoch 159/200
# 57/57 [==============================] - 2s 34ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6125
# Epoch 160/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6250
# Epoch 161/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6500
# Epoch 162/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5750
# Epoch 163/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 164/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6125
# Epoch 165/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6125
# Epoch 166/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5750
# Epoch 167/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5750
# Epoch 168/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6125
# Epoch 169/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 170/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5625
# Epoch 171/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 172/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 173/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6500
# Epoch 174/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6125
# Epoch 175/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 176/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6250
# Epoch 177/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6125
# Epoch 178/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6375
# Epoch 179/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6125
# Epoch 180/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6125
# Epoch 181/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 182/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6125
# Epoch 183/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5750
# Epoch 184/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 185/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5500
# Epoch 186/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 187/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 188/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6250
# Epoch 189/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6125
# Epoch 190/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 191/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 192/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6125
# Epoch 193/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6125
# Epoch 194/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6250
# Epoch 195/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6125
# Epoch 196/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5625
# Epoch 197/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5625
# Epoch 198/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6250
# Epoch 199/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5750
# Epoch 200/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6250
# Finished training!

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
# import pickle
# with open("./cnn_model_test00",'wb') as file_pi:
#     pickle.dump(history_fine.history, file_pi)

# %%
# test_load = pickle.load(open("./cnn_model_test00",'rb'))
# test_load['loss']

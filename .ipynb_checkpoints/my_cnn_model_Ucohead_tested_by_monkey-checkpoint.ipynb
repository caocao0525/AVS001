# %% [markdown]
# ## MY CNN model for Ucohead with the model tested 10-mokey-species
#
# Test CNN model
# as following the tutorial : https://www.tensorflow.org/tutorials/images/classification

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
tf.config.list_physical_devices("GPU")
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'),
#  PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %%
BATCH_SIZE = 32
# IMG_SIZE = (500,500)
# IMG_W = 500
# IMG_H = 500
IMG_SIZE = (40,40)
IMG_W = 40
IMG_H = 40
# IMG_SIZE = (200,200)
# IMG_W = 200
# IMG_H = 200

# %%
train_dataset = image_dataset_from_directory("../dataset/train/",
                                            shuffle=True,
                                            batch_size=BATCH_SIZE,
                                            image_size=IMG_SIZE)
# Out:
# Found 7818 files belonging to 10 classes.

# %%
validation_dataset = image_dataset_from_directory("../dataset/test/",
                                                 shuffle=True,
                                                 batch_size=BATCH_SIZE,
                                                 image_size=IMG_SIZE)
# Out:
# Found 3806 files belonging to 10 classes.

# %%
class_names = train_dataset.class_names
class_names
# Out:
# ['n0', 'n1', 'n2', 'n3', 'n4', 'n5', 'n6', 'n7', 'n8', 'n9']

# %%
plt.figure(figsize=(5,5))
for images, labels in train_dataset.take(1):
    first_image=images[0]
    for i in range(9):
        ax = plt.subplot(3,3,i+1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %%
for image_batch, labels_batch in train_dataset:
    print(image_batch.shape)
    print(labels_batch.shape)
    break
# Out:
# (32, 40, 40, 3)
# (32,)

# %%
first_image.shape
# Out:
# TensorShape([40, 40, 3])

# %%
# AUTOTUNE =tf.data.experimental.AUTOTUNE

# train_dataset = train_dataset.prefetch(buffer_size=AUTOTUNE)
# validation_dataset = validation_dataset.prefetch(buffer_size=AUTOTUNE)
# test_dataset = test_dataset.prefetch(buffer_size=AUTOTUNE)

AUTOTUNE =tf.data.experimental.AUTOTUNE

train_dataset = train_dataset.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
validation_dataset = validation_dataset.cache().prefetch(buffer_size=AUTOTUNE)

# %%
from tensorflow.keras import layers

# %%
data_augmentation = keras.Sequential([
#     layers.experimental.preprocessing.RandomFlip("horizontal", input_shape=(IMG_H, IMG_W, 3)),
#     layers.experimental.preprocessing.RandomRotation(0.1),
    layers.experimental.preprocessing.RandomZoom(0.1, input_shape=(IMG_H, IMG_W, 3)),
    layers.experimental.preprocessing.RandomTranslation(height_factor=0.2, width_factor=0.2)
])

# %% [markdown]
# #### Standardize the data
#
# The RGB channel values are in the ```[0, 255]``` range. This is not ideal for a neural network; in general you should seek to make your input values small. Here, you will standardize values to be in the ```[0,1]``` range by using a Rescaling layer.

# %%
normalized_layer = layers.experimental.preprocessing.Rescaling(1./255)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D, BatchNormalization, Dropout

# %%
num_classes = 10
model = Sequential([
#     layers.experimental.preprocessing.Rescaling(1./255, input_shape=(IMG_H, IMG_W, 3)),
    data_augmentation,
    layers.experimental.preprocessing.Rescaling(1./255),
    layers.Conv2D(16, 3, padding = "same", activation ="relu"),
    layers.MaxPool2D(),
    layers.Conv2D(32, 3, padding = "same", activation ="relu"),
    layers.MaxPool2D(),
    layers.Conv2D(64, 3, padding = "same", activation ="relu"),
    layers.Dropout(0.2),
    layers.MaxPool2D(),
    layers.Dropout(0.2),
    layers.Flatten(),
    layers.Dense(128, activation = 'relu'),
    layers.Dense(num_classes)
])

# %%
# #### Ucohead original


# def my_model(input_shape, drop_rate): # dr0.2/
#     model = Sequential([
#         Conv2D(filters=32, input_shape=input_shape, kernel_size=(3,3), strides=2, activation = 'relu'),
#         Dropout(drop_rate),
#         Conv2D(filters=32, kernel_size=(3,3), activation='relu'),
#         Dropout(drop_rate),
#         Dense(units=32, activation='relu')
# #         Dense(units=1, activation='softmax')
#     ])
#     return model

# %%
# drop_rate = 0.5 #looks it works better than 0.5

# model = my_model(first_image.shape, drop_rate)

# %%
model.compile(optimizer='adam', loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
             metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential_3 (Sequential)    (None, 40, 40, 3)         0
# _________________________________________________________________
# rescaling_5 (Rescaling)      (None, 40, 40, 3)         0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 40, 40, 16)        448
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 20, 20, 16)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 20, 20, 32)        4640
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 10, 10, 32)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 10, 10, 64)        18496
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 10, 10, 64)        0
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 5, 5, 64)          0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 5, 5, 64)          0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 1600)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               204928
# _________________________________________________________________
# dense_7 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 229,802
# Trainable params: 229,802
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs=200
history = model.fit(train_dataset, validation_data=validation_dataset, epochs=epochs)
# Out:
# Epoch 1/200
# 245/245 [==============================] - 1s 5ms/step - loss: 1.7571 - accuracy: 0.3377 - val_loss: 1.1052 - val_accuracy: 0.5912
# Epoch 2/200
# 245/245 [==============================] - 1s 5ms/step - loss: 1.0652 - accuracy: 0.5876 - val_loss: 0.8300 - val_accuracy: 0.6860
# Epoch 3/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.8529 - accuracy: 0.6623 - val_loss: 0.6574 - val_accuracy: 0.7420
# Epoch 4/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.7273 - accuracy: 0.7144 - val_loss: 0.5872 - val_accuracy: 0.7596
# Epoch 5/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.6476 - accuracy: 0.7397 - val_loss: 0.5378 - val_accuracy: 0.7893
# Epoch 6/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.5865 - accuracy: 0.7678 - val_loss: 0.4450 - val_accuracy: 0.8287
# Epoch 7/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.5343 - accuracy: 0.7887 - val_loss: 0.4363 - val_accuracy: 0.8263
# Epoch 8/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.5033 - accuracy: 0.8002 - val_loss: 0.4087 - val_accuracy: 0.8355
# Epoch 9/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.4750 - accuracy: 0.8099 - val_loss: 0.3878 - val_accuracy: 0.8523
# Epoch 10/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.4383 - accuracy: 0.8280 - val_loss: 0.3906 - val_accuracy: 0.8445
# Epoch 11/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.4113 - accuracy: 0.8363 - val_loss: 0.3576 - val_accuracy: 0.8631
# Epoch 12/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.3924 - accuracy: 0.8448 - val_loss: 0.3479 - val_accuracy: 0.8650
# Epoch 13/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.3813 - accuracy: 0.8491 - val_loss: 0.3334 - val_accuracy: 0.8778
# Epoch 14/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.3572 - accuracy: 0.8594 - val_loss: 0.3212 - val_accuracy: 0.8797
# Epoch 15/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.3334 - accuracy: 0.8645 - val_loss: 0.2986 - val_accuracy: 0.8889
# Epoch 16/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.3291 - accuracy: 0.8734 - val_loss: 0.2913 - val_accuracy: 0.8886
# Epoch 17/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.3213 - accuracy: 0.8743 - val_loss: 0.2875 - val_accuracy: 0.8978
# Epoch 18/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.3007 - accuracy: 0.8855 - val_loss: 0.2792 - val_accuracy: 0.8962
# Epoch 19/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.2898 - accuracy: 0.8872 - val_loss: 0.2763 - val_accuracy: 0.9009
# Epoch 20/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.2658 - accuracy: 0.8969 - val_loss: 0.2800 - val_accuracy: 0.8975
# Epoch 21/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.2780 - accuracy: 0.8955 - val_loss: 0.2627 - val_accuracy: 0.9104
# Epoch 22/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.2563 - accuracy: 0.9001 - val_loss: 0.2758 - val_accuracy: 0.9002
# Epoch 23/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.2527 - accuracy: 0.9039 - val_loss: 0.2667 - val_accuracy: 0.9038
# Epoch 24/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.2503 - accuracy: 0.9033 - val_loss: 0.2434 - val_accuracy: 0.9096
# Epoch 25/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.2464 - accuracy: 0.9025 - val_loss: 0.2525 - val_accuracy: 0.9091
# Epoch 26/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.2365 - accuracy: 0.9080 - val_loss: 0.2764 - val_accuracy: 0.8939
# Epoch 27/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.2172 - accuracy: 0.9176 - val_loss: 0.2572 - val_accuracy: 0.9122
# Epoch 28/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.2242 - accuracy: 0.9121 - val_loss: 0.2641 - val_accuracy: 0.9036
# Epoch 29/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.2237 - accuracy: 0.9142 - val_loss: 0.2572 - val_accuracy: 0.9083
# Epoch 30/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.2159 - accuracy: 0.9156 - val_loss: 0.2732 - val_accuracy: 0.9075
# Epoch 31/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.2012 - accuracy: 0.9263 - val_loss: 0.2393 - val_accuracy: 0.9143
# Epoch 32/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.1930 - accuracy: 0.9259 - val_loss: 0.2796 - val_accuracy: 0.8986
# Epoch 33/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.1871 - accuracy: 0.9303 - val_loss: 0.2410 - val_accuracy: 0.9172
# Epoch 34/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.1903 - accuracy: 0.9244 - val_loss: 0.2711 - val_accuracy: 0.9122
# Epoch 35/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.1835 - accuracy: 0.9284 - val_loss: 0.2545 - val_accuracy: 0.9141
# Epoch 36/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.1860 - accuracy: 0.9272 - val_loss: 0.2657 - val_accuracy: 0.9091
# Epoch 37/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.1820 - accuracy: 0.9302 - val_loss: 0.2806 - val_accuracy: 0.9023
# Epoch 38/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.1768 - accuracy: 0.9346 - val_loss: 0.2448 - val_accuracy: 0.9178
# Epoch 39/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.1711 - accuracy: 0.9330 - val_loss: 0.2381 - val_accuracy: 0.9180
# Epoch 40/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.1772 - accuracy: 0.9344 - val_loss: 0.2562 - val_accuracy: 0.9096
# Epoch 41/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.1661 - accuracy: 0.9394 - val_loss: 0.2302 - val_accuracy: 0.9207
# Epoch 42/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.1668 - accuracy: 0.9351 - val_loss: 0.2633 - val_accuracy: 0.9115
# Epoch 43/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.1554 - accuracy: 0.9408 - val_loss: 0.2397 - val_accuracy: 0.9183
# Epoch 44/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.1487 - accuracy: 0.9418 - val_loss: 0.2436 - val_accuracy: 0.9212
# Epoch 45/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.1552 - accuracy: 0.9422 - val_loss: 0.2355 - val_accuracy: 0.9238
# Epoch 46/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.1461 - accuracy: 0.9456 - val_loss: 0.2484 - val_accuracy: 0.9191
# Epoch 47/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.1373 - accuracy: 0.9463 - val_loss: 0.2460 - val_accuracy: 0.9185
# Epoch 48/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.1438 - accuracy: 0.9438 - val_loss: 0.2369 - val_accuracy: 0.9204
# Epoch 49/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.1487 - accuracy: 0.9432 - val_loss: 0.2736 - val_accuracy: 0.9094
# Epoch 50/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.1506 - accuracy: 0.9424 - val_loss: 0.2500 - val_accuracy: 0.9180
# Epoch 51/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.1510 - accuracy: 0.9435 - val_loss: 0.2515 - val_accuracy: 0.9214
# Epoch 52/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.1433 - accuracy: 0.9458 - val_loss: 0.2346 - val_accuracy: 0.9256
# Epoch 53/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.1287 - accuracy: 0.9532 - val_loss: 0.2458 - val_accuracy: 0.9212
# Epoch 54/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.1328 - accuracy: 0.9493 - val_loss: 0.2464 - val_accuracy: 0.9201
# Epoch 55/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.1444 - accuracy: 0.9456 - val_loss: 0.2680 - val_accuracy: 0.9096
# Epoch 56/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.1248 - accuracy: 0.9548 - val_loss: 0.2500 - val_accuracy: 0.9175
# Epoch 57/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.1318 - accuracy: 0.9485 - val_loss: 0.2669 - val_accuracy: 0.9154
# Epoch 58/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.1336 - accuracy: 0.9493 - val_loss: 0.2762 - val_accuracy: 0.9146
# Epoch 59/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.1224 - accuracy: 0.9541 - val_loss: 0.2410 - val_accuracy: 0.9235
# Epoch 60/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.1275 - accuracy: 0.9499 - val_loss: 0.2653 - val_accuracy: 0.9193
# Epoch 61/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.1272 - accuracy: 0.9527 - val_loss: 0.2414 - val_accuracy: 0.9256
# Epoch 62/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.1310 - accuracy: 0.9509 - val_loss: 0.2454 - val_accuracy: 0.9243
# Epoch 63/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.1216 - accuracy: 0.9533 - val_loss: 0.2623 - val_accuracy: 0.9188
# Epoch 64/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.1218 - accuracy: 0.9556 - val_loss: 0.2399 - val_accuracy: 0.9262
# Epoch 65/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.1154 - accuracy: 0.9550 - val_loss: 0.2546 - val_accuracy: 0.9217
# Epoch 66/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.1164 - accuracy: 0.9573 - val_loss: 0.2403 - val_accuracy: 0.9254
# Epoch 67/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.1169 - accuracy: 0.9559 - val_loss: 0.2519 - val_accuracy: 0.9272
# Epoch 68/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.1206 - accuracy: 0.9546 - val_loss: 0.2587 - val_accuracy: 0.9209
# Epoch 69/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.1115 - accuracy: 0.9580 - val_loss: 0.2557 - val_accuracy: 0.9225
# Epoch 70/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.1142 - accuracy: 0.9546 - val_loss: 0.2442 - val_accuracy: 0.9220
# Epoch 71/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.1147 - accuracy: 0.9557 - val_loss: 0.2561 - val_accuracy: 0.9222
# Epoch 72/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.1138 - accuracy: 0.9573 - val_loss: 0.2901 - val_accuracy: 0.9136
# Epoch 73/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.1222 - accuracy: 0.9543 - val_loss: 0.2540 - val_accuracy: 0.9228
# Epoch 74/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.1090 - accuracy: 0.9593 - val_loss: 0.2444 - val_accuracy: 0.9283
# Epoch 75/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.1057 - accuracy: 0.9611 - val_loss: 0.2569 - val_accuracy: 0.9267
# Epoch 76/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.1051 - accuracy: 0.9632 - val_loss: 0.2734 - val_accuracy: 0.9233
# Epoch 77/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.1136 - accuracy: 0.9583 - val_loss: 0.2514 - val_accuracy: 0.9254
# Epoch 78/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.1055 - accuracy: 0.9598 - val_loss: 0.2598 - val_accuracy: 0.9235
# Epoch 79/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.1080 - accuracy: 0.9587 - val_loss: 0.2360 - val_accuracy: 0.9264
# Epoch 80/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.1063 - accuracy: 0.9586 - val_loss: 0.2676 - val_accuracy: 0.9201
# Epoch 81/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.1106 - accuracy: 0.9572 - val_loss: 0.2758 - val_accuracy: 0.9209
# Epoch 82/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.0967 - accuracy: 0.9635 - val_loss: 0.2583 - val_accuracy: 0.9241
# Epoch 83/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.0993 - accuracy: 0.9641 - val_loss: 0.2752 - val_accuracy: 0.9228
# Epoch 84/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.1000 - accuracy: 0.9643 - val_loss: 0.2795 - val_accuracy: 0.9220
# Epoch 85/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.1046 - accuracy: 0.9601 - val_loss: 0.2523 - val_accuracy: 0.9270
# Epoch 86/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.0964 - accuracy: 0.9651 - val_loss: 0.2579 - val_accuracy: 0.9296
# Epoch 87/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.0967 - accuracy: 0.9667 - val_loss: 0.2755 - val_accuracy: 0.9283
# Epoch 88/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.1004 - accuracy: 0.9635 - val_loss: 0.2725 - val_accuracy: 0.9264
# Epoch 89/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.0912 - accuracy: 0.9674 - val_loss: 0.2725 - val_accuracy: 0.9220
# Epoch 90/200
# 245/245 [==============================] - 1s 5ms/step - loss: 0.0884 - accuracy: 0.9699 - val_loss: 0.2819 - val_accuracy: 0.9217

# %%
# prediction_layer = tf.keras.layers.Dense(10, activation="softmax")  
# #default -linear, 0.5375
# #softmax, 0.4000
# #relu, 0.6250

# %%
# inputs = tf.keras.Input(shape=(IMG_W, IMG_H, 3))
# # x = data_augmentation(inputs)
# x = inputs
# # x = rescale(x)
# x = model(x)
# outputs = prediction_layer(x)
# cnn_model = tf.keras.Model(inputs, outputs)

# %%
# new_img_path = "../large.jpg"

new_img_path ="../side_view.jpg"

new_img = keras.preprocessing.image.load_img(new_img_path, target_size=(IMG_H, IMG_W, 3))
img_array = keras.preprocessing.image.img_to_array(new_img)
img_array = tf.expand_dims(img_array, 0) # create a batch

prediction = model.predict(img_array)
score = tf.nn.softmax(prediction[0])

print("This image most likely belongs to {} with {:.2f} percent confidence.". format(class_names[np.argmax(score)], 100*np.max(score)))
# Out:
# This image most likely belongs to n3 with 70.54 percent confidence.

# %%
# base_lr = 0.0001
# cnn_model.compile(optimizer=tf.keras.optimizers.Adam(lr=base_lr), 
# #                   loss = tf.keras.losses.categorical_crossentropy(from_logits=True),
#                   loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
#                   metrics=['accuracy'])

# %%
# from tensorflow.keras.callbacks import Callback, ModelCheckpoint, EarlyStopping

# class TrainingCallback(Callback):
#     def on_train_begin(self, logs=None):
#         print("Starting training ...")
#     def on_train_end(self, logs=None):
#         print("Finished training!")

# early_stopping = EarlyStopping(monitor='val_accuracy', verbose=1, patience=5)

# %%
# initial_epochs = 200
# loss0, accuracy0 = cnn_model.evaluate(validation_dataset)

# %%
# print("initial loss : {:.2f}".format(loss0))
# print("initial accuracy : {:.2f}".format(accuracy0))

# %%
# # history = cnn_model.fit(train_dataset,
# #                        epochs=initial_epochs,
# #                        validation_data=validation_dataset,
# #                        callbacks=[TrainingCallback(), early_stopping])
# history = cnn_model.fit(train_dataset,
#                        epochs=initial_epochs,
#                        validation_data=validation_dataset,
#                        callbacks=[TrainingCallback()])

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,3.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
# import pickle
# with open("./cnn_model_test00",'wb') as file_pi:
#     pickle.dump(history_fine.history, file_pi)

# %%
# test_load = pickle.load(open("./cnn_model_test00",'rb'))
# test_load['loss']

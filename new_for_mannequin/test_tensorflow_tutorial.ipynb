# %% [markdown]
# ### Tutorial for image classification using Keras
#
#
# https://www.tensorflow.org/tutorials/images/classification

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
print(tf.__version__)
# Out:
# 2.5.0-dev20201129

# %%
import pathlib
dataset_url="https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"
data_dir=tf.keras.utils.get_file("flower_photos", origin=dataset_url, untar=True)
data_dir=pathlib.Path(data_dir)

# %%
image_count=len(list(data_dir.glob("*/*.jpg")))
print(image_count)
# Out:
# 3670

# %%
roses=list(data_dir.glob('roses/*'))
PIL.Image.open(str(roses[1]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x333 at 0x7F7C1B058F50>

# %%
PIL.Image.open(str(roses[2]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x240 at 0x7F7C1B07CF90>

# %%
tulips=list(data_dir.glob('tulips/*'))
PIL.Image.open(str(tulips[3]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x334 at 0x7F7C08A8A0D0>

# %%
PIL.Image.open(str(tulips[6]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x213 at 0x7F7C1B08CAD0>

# %%
batch_size=32
img_height=180
img_width=180

# %%
train_ds=keras.utils.image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset='training',
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-49521f629127> in <module>
# ----> 1 train_ds=keras.utils.image_dataset_from_directory(
#       2     data_dir,
#       3     validation_split=0.2,
#       4     subset='training',
#       5     seed=123,
#
# AttributeError: module 'tensorflow.keras.utils' has no attribute 'image_dataset_from_directory'

# %%
# !pip install tf-nightly
# Out:
# Requirement already satisfied: tf-nightly in /Users/schona/opt/anaconda3/lib/python3.7/site-packages (2.5.0.dev20201129)
# Requirement already satisfied: termcolor~=1.1.0 in /Users/schona/opt/anaconda3/lib/python3.7/site-packages (from tf-nightly) (1.1.0)
# Requirement already satisfied: grpcio~=1.32.0 in /Users/schona/opt/anaconda3/lib/python3.7/site-packages (from tf-nightly) (1.32.0)
# Requirement already satisfied: gast==0.3.3 in /Users/schona/opt/anaconda3/lib/python3.7/site-packages (from tf-nightly) (0.3.3)
# Requirement already satisfied: wrapt~=1.12.1 in /Users/schona/opt/anaconda3/lib/python3.7/site-packages (from tf-nightly) (1.12.1)
# Requirement already satisfied: google-pasta~=0.2 in /Users/schona/opt/anaconda3/lib/python3.7/site-packages (from tf-nightly) (0.2.0)
# Requirement already satisfied: wheel~=0.35 in /Users/schona/opt/anaconda3/lib/python3.7/site-packages (from tf-nightly) (0.35.1)
# Requirement already satisfied: absl-py~=0.10 in /Users/schona/opt/anaconda3/lib/python3.7/site-packages (from tf-nightly) (0.11.0)
# Requirement already satisfied: tf-estimator-nightly~=2.4.0.dev in /Users/schona/opt/anaconda3/lib/python3.7/site-packages (from tf-nightly) (2.4.0.dev2020102301)
# Requirement already satisfied: opt-einsum~=3.3.0 in /Users/schona/opt/anaconda3/lib/python3.7/site-packages (from tf-nightly) (3.3.0)
# Requirement already satisfied: tb-nightly~=2.5.0.a in /Users/schona/opt/anaconda3/lib/python3.7/site-packages (from tf-nightly) (2.5.0a20201129)
# Requirement already satisfied: numpy~=1.19.2 in /Users/schona/opt/anaconda3/lib/python3.7/site-packages (from tf-nightly) (1.19.4)
# Requirement already satisfied: protobuf~=3.13.0 in /Users/schona/opt/anaconda3/lib/python3.7/site-packages (from tf-nightly) (3.13.0)
# Requirement already satisfied: astunparse~=1.6.3 in /Users/schona/opt/anaconda3/lib/python3.7/site-packages (from tf-nightly) (1.6.3)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /Users/schona/opt/anaconda3/lib/python3.7/site-packages (from tf-nightly) (1.1.2)
# Requirement already satisfied: flatbuffers~=1.12.0 in /Users/schona/opt/anaconda3/lib/python3.7/site-packages (from tf-nightly) (1.12)
# Requirement already satisfied: typing-extensions~=3.7.4 in /Users/schona/opt/anaconda3/lib/python3.7/site-packages (from tf-nightly) (3.7.4.3)
# Requirement already satisfied: h5py~=2.10.0 in /Users/schona/opt/anaconda3/lib/python3.7/site-packages (from tf-nightly) (2.10.0)
# Requirement already satisfied: six~=1.15.0 in /Users/schona/opt/anaconda3/lib/python3.7/site-packages (from tf-nightly) (1.15.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/schona/opt/anaconda3/lib/python3.7/site-packages (from tb-nightly~=2.5.0.a->tf-nightly) (3.3.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/schona/opt/anaconda3/lib/python3.7/site-packages (from tb-nightly~=2.5.0.a->tf-nightly) (2.24.0)
# Requirement already satisfied: setuptools>=41.0.0 in /Users/schona/opt/anaconda3/lib/python3.7/site-packages (from tb-nightly~=2.5.0.a->tf-nightly) (50.3.0.post20201006)
# Requirement already satisfied: werkzeug>=0.11.15 in /Users/schona/opt/anaconda3/lib/python3.7/site-packages (from tb-nightly~=2.5.0.a->tf-nightly) (1.0.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/schona/opt/anaconda3/lib/python3.7/site-packages (from tb-nightly~=2.5.0.a->tf-nightly) (1.7.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /Users/schona/opt/anaconda3/lib/python3.7/site-packages (from tb-nightly~=2.5.0.a->tf-nightly) (0.4.2)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /Users/schona/opt/anaconda3/lib/python3.7/site-packages (from tb-nightly~=2.5.0.a->tf-nightly) (1.23.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /Users/schona/opt/anaconda3/lib/python3.7/site-packages (from markdown>=2.6.8->tb-nightly~=2.5.0.a->tf-nightly) (1.7.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/schona/opt/anaconda3/lib/python3.7/site-packages (from requests<3,>=2.21.0->tb-nightly~=2.5.0.a->tf-nightly) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /Users/schona/opt/anaconda3/lib/python3.7/site-packages (from requests<3,>=2.21.0->tb-nightly~=2.5.0.a->tf-nightly) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/schona/opt/anaconda3/lib/python3.7/site-packages (from requests<3,>=2.21.0->tb-nightly~=2.5.0.a->tf-nightly) (1.25.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/schona/opt/anaconda3/lib/python3.7/site-packages (from requests<3,>=2.21.0->tb-nightly~=2.5.0.a->tf-nightly) (3.0.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/schona/opt/anaconda3/lib/python3.7/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tb-nightly~=2.5.0.a->tf-nightly) (1.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/schona/opt/anaconda3/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tb-nightly~=2.5.0.a->tf-nightly) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /Users/schona/opt/anaconda3/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tb-nightly~=2.5.0.a->tf-nightly) (4.1.1)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.5" in /Users/schona/opt/anaconda3/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tb-nightly~=2.5.0.a->tf-nightly) (4.6)
# Requirement already satisfied: zipp>=0.5 in /Users/schona/opt/anaconda3/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tb-nightly~=2.5.0.a->tf-nightly) (3.3.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/schona/opt/anaconda3/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tb-nightly~=2.5.0.a->tf-nightly) (3.1.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/schona/opt/anaconda3/lib/python3.7/site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tb-nightly~=2.5.0.a->tf-nightly) (0.4.8)
